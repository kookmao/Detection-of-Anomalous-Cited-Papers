# %% [markdown]
# <a href="https://colab.research.google.com/github/kookmao/Detection-of-Anomalous-Cited-Papers/blob/main/CITAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # init environment

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda create -n myenv python=3.8 -y
# !conda init myenv
# !conda activate myenv
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h4bc722e_7         247 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     ld_impl_linux-64-2.43      |       h712a8e2_2         654 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
# ...

# %% [markdown]
# # **install dependencies**
#
# ---

# %%
# !conda install -n myenv pytorch=1.7.1 torchvision torchaudio cudatoolkit=10.1 -c pytorch -y
# !conda install -n myenv transformers=3.5.1 scipy=1.5.2 numpy=1.19.2 networkx=2.5 scikit-learn=0.23.2 -y
# !conda install -n myenv matplotlib -y
# !conda install -n myenv ipykernel -y
# !conda install -n myenv matplotlib -y
# !conda install -n myenv ipykernel -y
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/conda_libmamba_solver/models.py", line 87, in _set
#     old = self._data[key]
# KeyError: 'pytorch'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/site-packages/conda/exception_handler.py", line 17, in __call__
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/site-packages/conda/cli/main.py", line 83, in main_subshell
#     exit_code = do_call(args, parser)
#   File "/usr/local/lib/python3.10/site-packages/conda/cli/conda_argparse.py", line 194, in do_call
#     result = getattr(module, func_name)(args, parser)
#   File "/usr/local/lib/python3.10/site-packages/conda/notices/core.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/site-packages/conda/cli/main_install.py", line 140, in execute
# ...

# %% [markdown]
# # **prepare data:**

# %%
# !conda run -n myenv python 0_prepare_data.py --dataset btc_alpha
# Out:
# Generating data with anomaly for Dataset:  btc_alpha
# [#s] generating anomalous dataset...
#  2024-12-11 00:36:30.758278
# [#s] initial network edge percent: #.1f##, anomaly percent: #.1f##.
#  2024-12-11 00:36:30.758303 50.0 1.0
# Anomaly Generation finish! Time: 13.09 s
# Train size:7062  7  Test size:7132 7
# Training dataset contruction finish! Time: 0.01 s
# Test dataset finish constructing! Time: 0.00 s
# Generating data with anomaly for Dataset:  btc_alpha
# [#s] generating anomalous dataset...
#  2024-12-11 00:36:45.267228
# [#s] initial network edge percent: #.1f##, anomaly percent: #.1f##.
#  2024-12-11 00:36:45.267252 50.0 5.0
# Anomaly Generation finish! Time: 13.43 s
# Train size:7062  7  Test size:7415 7
# Training dataset contruction finish! Time: 0.01 s
# Test dataset finish constructing! Time: 0.00 s
# Generating data with anomaly for Dataset:  btc_alpha
# [#s] generating anomalous dataset...
#  2024-12-11 00:37:00.040184
# ...

# %% [markdown]
# # **train data**

# %%
# !conda run -n myenv python 1_train.py --dataset btc_alpha --anomaly_per 0.1
# Out:
# $$$$ Start $$$$
# Loading btc_alpha dataset...
# Loading eigen from: data/eigen/btc_alpha_0.5_0.1.pkl
# Figure(800x800)
# Figure(800x800)
# Epoch: 1, loss:0.6812, Time: 10.4911s
# Figure(800x800)
# Epoch: 2, loss:0.6478, Time: 9.0654s
# Figure(800x800)
# Epoch: 3, loss:0.5975, Time: 8.1460s
# Figure(800x800)
# Epoch: 4, loss:0.5328, Time: 9.3500s
# Figure(800x800)
# Epoch: 5, loss:0.4616, Time: 8.0462s
# Figure(800x800)
# Epoch: 6, loss:0.4057, Time: 10.1640s
# Figure(800x800)
# Epoch: 7, loss:0.3603, Time: 9.6311s
# Figure(800x800)
# Epoch: 8, loss:0.3325, Time: 8.0623s
# Figure(800x800)
# Epoch: 9, loss:0.3080, Time: 9.9479s
# Figure(800x800)
# Epoch: 10, loss:0.2857, Time: 8.4666s
# Snap: 07 | AUC: 0.9086
# Snap: 08 | AUC: 0.9161
# Snap: 09 | AUC: 0.9421
# Snap: 10 | AUC: 0.9510
# Snap: 11 | AUC: 0.9545
# Snap: 12 | AUC: 0.9372
# Snap: 13 | AUC: 0.9503
# Snap: 14 | AUC: 0.9548
# TOTAL AUC:0.9384
# Snapshot 0 Anomalous Edges: [[   9  270]
#  [  53  118]
#  [  53  270]
# ...
